# %%
import time
import os

# %%
print("Processes start")
command = "./bin/main_icp " \
        + f"--sequence_dir=/data/datasets/dataset_std/park_avia_01 " \
        + f"--method=icp"
print(command)
os.system(command)
# Out:
# Processes start
# ./bin/main_icp --sequence_dir=/data/datasets/dataset_std/park_avia_01 --method=icp
# timestamp: 1577838951.099972, scan_path: lidar/000000.pcd
# timestamp: 1577838951.199816, scan_path: lidar/000001.pcd
# timestamp: 1577838951.399513, scan_path: lidar/000002.pcd
# timestamp: 1577838951.399513, scan_path: lidar/000003.pcd
# timestamp: 1577838951.499351, scan_path: lidar/000004.pcd
# timestamp: 1577838951.599601, scan_path: lidar/000005.pcd
# timestamp: 1577838951.699434, scan_path: lidar/000006.pcd
# timestamp: 1577838951.799282, scan_path: lidar/000007.pcd
# timestamp: 1577838951.899921, scan_path: lidar/000008.pcd
# timestamp: 1577838951.999744, scan_path: lidar/000009.pcd
# timestamp: 1577838952.099567, scan_path: lidar/000010.pcd
# timestamp: 1577838952.199405, scan_path: lidar/000011.pcd
# timestamp: 1577838952.399468, scan_path: lidar/000012.pcd
# timestamp: 1577838952.499303, scan_path: lidar/000013.pcd
# ...
